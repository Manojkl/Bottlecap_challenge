# %% [markdown]
# <a href="https://colab.research.google.com/github/Manojkl/Bottlecap_challenge/blob/main/YOLOV3_training.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os
os.chdir('/content/drive/MyDrive/YOLOV3/darknet/')

# %%
# !nvidia-smi
# Out:
# Sat Dec 19 23:00:15 2020
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 455.45.01    Driver Version: 418.67       CUDA Version: 10.1     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   35C    P8     9W /  70W |      0MiB / 15079MiB |      0%      Default |
# |                               |                      |                 ERR! |
# +-------------------------------+----------------------+----------------------+
#
# ...

# %%
# !apt install gcc-5 g++-5 -y
# !ln -s /usr/bin/gcc-5 /usr/local/cuda/bin/gcc 
# !ln -s /usr/bin/g++-5 /usr/local/cuda/bin/g++
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# g++-5 is already the newest version (5.5.0-12ubuntu1).
# gcc-5 is already the newest version (5.5.0-12ubuntu1).
# 0 upgraded, 0 newly installed, 0 to remove and 14 not upgraded.
# ln: failed to create symbolic link '/usr/local/cuda/bin/gcc': File exists
# ln: failed to create symbolic link '/usr/local/cuda/bin/g++': File exists

# %%
# !chmod a+x ./darknet

# %%
# !make
# Out:
# chmod +x *.sh
# g++ -std=c++11 -std=c++11 -Iinclude/ -I3rdparty/stb/include -DGPU -I/usr/local/cuda/include/ -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DGPU -c ./src/image_opencv.cpp -o obj/image_opencv.o
# g++ -std=c++11 -std=c++11 -Iinclude/ -I3rdparty/stb/include -DGPU -I/usr/local/cuda/include/ -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DGPU -c ./src/http_stream.cpp -o obj/http_stream.o
# ./src/http_stream.cpp: In member function ‘bool JSON_sender::write(const char*)’:
# ./src/http_stream.cpp:249:21: warning: unused variable ‘n’ [-Wunused-variable]
#                  int n = _write(client, outputbuf, outlen);
#                      ^
# ./src/http_stream.cpp: In function ‘void set_track_id(detection*, int, float, float, float, int, int, int)’:
# ./src/http_stream.cpp:863:27: warning: comparison between signed and unsigned integer expressions [-Wsign-compare]
#          for (int i = 0; i < v.size(); ++i) {
# ...

# %%
# !pwd
# Out:
# /content/drive/My Drive/YOLOV3/darknet

# %%
# !./darknet detector train ../data/obj.data cfg/yolo-obj.cfg ../data/darknet53.conv.74
# Out:
# Streaming output truncated to the last 5000 lines.
#  total_bbox = 10354, rewritten_bbox = 0.000000 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 82 Avg (IOU: 0.000000), count: 1, class_loss = 86.147606, iou_loss = 0.000000, total_loss = 86.147606
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 94 Avg (IOU: 0.000000), count: 1, class_loss = 308.398865, iou_loss = 0.000000, total_loss = 308.398865
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 106 Avg (IOU: 0.315465), count: 26, class_loss = 1748.961182, iou_loss = 26.026245, total_loss = 1774.987427
#  total_bbox = 10380, rewritten_bbox = 0.000000 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 82 Avg (IOU: 0.000000), count: 1, class_loss = 85.992432, iou_loss = 0.000000, total_loss = 85.992432
# ...

# %%
# !./darknet detector test ../data/obj.data cfg/yolo-obj.cfg backup/yolo-obj_1000.weights
# Out:
#  CUDA-version: 10010 (10010), GPU count: 1
#  OpenCV isn't used - data augmentation will be slow
# /content/drive/MyDrive/YOLOV3/data/images/CV20_image_18.png
# /content/drive/MyDrive/YOLOV3/data/images/CV20_image_18.png
# /content/drive/MyDrive/YOLOV3/data/images/CV20_image_18.png
# /content/drive/MyDrive/YOLOV3/data/images/CV20_image_18.png
# /content/drive/MyDrive/YOLOV3/data/images/CV20_image_18.png
# c
# stop
# ^C

# %%
# !./darknet detector test ../data/obj.data cfg/yolo-voc.cfg /content/drive/MyDrive/YOLOV3/darknet/backup/yolo-obj_last.weights -dont_show -ext_output < ../data/test.txt > ../data/result.txt
# Out:
# /bin/bash: ./darknet: Permission denied

# %%
# !make
# Out:
# chmod +x *.sh
