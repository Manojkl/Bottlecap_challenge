# %% [markdown]
# <a href="https://colab.research.google.com/github/Manojkl/Bottlecap_challenge/blob/main/YOLOv3_testing.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !df -h

# %%
import os 
os.chdir('/content/drive/MyDrive/YOLOV3/darknet/')

# %% [markdown]
# # New Section

# %%
# !pip3 freeze > requirements.txt

# %%
# !pip list -v
# Out:
# Package                       Version         Location                               Installer
# ----------------------------- --------------- -------------------------------------- ---------
# absl-py                       0.10.0          /usr/local/lib/python3.6/dist-packages pip
# alabaster                     0.7.12          /usr/local/lib/python3.6/dist-packages pip
# albumentations                0.1.12          /usr/local/lib/python3.6/dist-packages pip
# altair                        4.1.0           /usr/local/lib/python3.6/dist-packages pip
# appdirs                       1.4.4           /usr/local/lib/python3.6/dist-packages pip
# argon2-cffi                   20.1.0          /usr/local/lib/python3.6/dist-packages pip
# asgiref                       3.3.1           /usr/local/lib/python3.6/dist-packages pip
# astor                         0.8.1           /usr/local/lib/python3.6/dist-packages pip
# ...

# %%
# !make
# Out:
# chmod +x *.sh

# %%
# !chmod +x document.sh

# %%
from google.colab import files

uploaded = files.upload()
# Out:
#      <input type="file" id="files-5424ca16-f1b4-4dc7-b71f-536048af9d83" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-5424ca16-f1b4-4dc7-b71f-536048af9d83">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>

# %%
! ./document.sh -v "CV20_video_7.avi" -r "/content/drive/MyDrive/YOLOV3/darknet/results/"
# Out:
# CV20_video_7.avi
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# ...

# %%
# !chmod +x ./darknet

# %%
# !./darknet detector train ../data/obj.data cfg/yolo-obj.cfg ../data/darknet53.conv.74 -dont_show
# Out:
#  CUDA-version: 10010 (10010), GPU count: 1
#  OpenCV version: 3.2.0
# ^C

# %%
# !./darknet detector test ../data/obj.data cfg/yolo-voc.cfg /content/drive/MyDrive/YOLOV3/darknet/backup/yolo-obj_1000.weights -dont_show -ext_output < ../data/test.txt > ../data/result.txt
# Out:
#  CUDA-version: 10010 (10010), GPU count: 1
#  OpenCV version: 3.2.0
# ^C

# %%
# !./darknet detector test ../data/obj.data cfg/yolo-obj.cfg backup/yolo-obj_last.weights
# Out:
#  CUDA-version: 10010 (10010), GPU count: 1
#  OpenCV version: 3.2.0
#  0 : compute_capability = 750, cudnn_half = 0, GPU: Tesla T4
# net.optimized_memory = 0
# mini_batch = 1, batch = 16, time_steps = 1, train = 0
#    layer   filters  size/strd(dil)      input                output
#    0 conv     32       3 x 3/ 1    416 x 416 x   3 ->  416 x 416 x  32 0.299 BF
#    1 conv     64       3 x 3/ 2    416 x 416 x  32 ->  208 x 208 x  64 1.595 BF
#    2 conv     32       1 x 1/ 1    208 x 208 x  64 ->  208 x 208 x  32 0.177 BF
#    3 conv     64       3 x 3/ 1    208 x 208 x  32 ->  208 x 208 x  64 1.595 BF
#    4 Shortcut Layer: 1,  wt = 0, wn = 0, outputs: 208 x 208 x  64 0.003 BF
#    5 conv    128       3 x 3/ 2    208 x 208 x  64 ->  104 x 104 x 128 1.595 BF
#    6 conv     64       1 x 1/ 1    104 x 104 x 128 ->  104 x 104 x  64 0.177 BF
#    7 conv    128       3 x 3/ 1    104 x 104 x  64 ->  104 x 104 x 128 1.595 BF
# ...

# %%
from google.colab import files

uploaded = files.upload()
# Out:
#      <input type="file" id="files-8434ecdf-b4b0-4c8b-bf62-d63769aebfe9" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-8434ecdf-b4b0-4c8b-bf62-d63769aebfe9">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving CV20_video_7.avi to CV20_video_7 (2).avi

# %%
# !./darknet detector test ../data/obj.data cfg/yolo-obj.cfg backup/yolo-obj_1000.weights -dont_show -ext_output -out train.json < train.txt
# Out:
#  CUDA-version: 10010 (10010), GPU count: 1
#  OpenCV version: 3.2.0
#  0 : compute_capability = 750, cudnn_half = 0, GPU: Tesla T4
# net.optimized_memory = 0
# mini_batch = 1, batch = 16, time_steps = 1, train = 0
#    layer   filters  size/strd(dil)      input                output
#    0 conv     32       3 x 3/ 1    416 x 416 x   3 ->  416 x 416 x  32 0.299 BF
#    1 conv     64       3 x 3/ 2    416 x 416 x  32 ->  208 x 208 x  64 1.595 BF
#    2 conv     32       1 x 1/ 1    208 x 208 x  64 ->  208 x 208 x  32 0.177 BF
#    3 conv     64       3 x 3/ 1    208 x 208 x  32 ->  208 x 208 x  64 1.595 BF
#    4 Shortcut Layer: 1,  wt = 0, wn = 0, outputs: 208 x 208 x  64 0.003 BF
#    5 conv    128       3 x 3/ 2    208 x 208 x  64 ->  104 x 104 x 128 1.595 BF
#    6 conv     64       1 x 1/ 1    104 x 104 x 128 ->  104 x 104 x  64 0.177 BF
#    7 conv    128       3 x 3/ 1    104 x 104 x  64 ->  104 x 104 x 128 1.595 BF
# ...

# %%
# !./darknet detector demo ../data/obj.data cfg/yolo-obj.cfg backup/yolo-obj_1000.weights -dont_show CV20_video_7.avi -i 0 -out_filename output6.avi

# !./darknet detector demo cfg/coco.data cfg/yolov4.cfg yolov4.weights test.mp4 -benchmark
# !./darknet detector demo cfg/coco.data cfg/yolov3.cfg yolov3.weights -dont_show test.mp4 -i 0 -out_filename output1.avi -thresh 0.7
# Out:
# Streaming output truncated to the last 5000 lines.
# BottleCap_FaceDown: 99%
# BottleCap_FaceDown: 98%
# BottleCap_FaceDown: 88%
# BottleCap_FaceDown: 87%
# BottleCap_FaceDown: 83%
# BottleCap_FaceDown: 77%
# BottleCap_FaceDown: 59%
# BottleCap_FaceDown: 56%
# BottleCap_FaceUp: 90%
#
# FPS:25.8 	 AVG_FPS:0.0
#
#  cvWriteFrame
# Objects:
#
# BottleCap_Deformed: 95%
# BottleCap_FaceDown: 100%
# BottleCap_FaceDown: 100%
# BottleCap_FaceDown: 100%
# BottleCap_FaceDown: 100%
# BottleCap_FaceDown: 100%
# BottleCap_FaceDown: 99%
# BottleCap_FaceDown: 99%
# BottleCap_FaceDown: 88%
# BottleCap_FaceDown: 88%
# BottleCap_FaceDown: 85%
# BottleCap_FaceDown: 78%
# BottleCap_FaceDown: 65%
# BottleCap_FaceDown: 53%
# BottleCap_FaceUp: 91%
#
# FPS:25.8 	 AVG_FPS:0.0
#
#  cvWriteFrame
# Objects:
#
# BottleCap_Deformed: 95%
# BottleCap_FaceDown: 100%
# BottleCap_FaceDown: 100%
# BottleCap_FaceDown: 100%
# BottleCap_FaceDown: 100%
# BottleCap_FaceDown: 100%
# BottleCap_FaceDown: 99%
# ...

# %%
from google.colab import files
files.download("output6.avi")
